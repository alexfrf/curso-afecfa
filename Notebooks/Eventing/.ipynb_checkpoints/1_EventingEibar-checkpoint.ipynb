# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
from mplsoccer.pitch import Pitch
import xml.etree.ElementTree as et
import os
from pathlib import Path

# %%
base_dir = os.path.join('',Path(os.getcwd()).parents[1])
data_dir = os.path.join(base_dir, 'Data/EventingEibar')
file = '07-02-2021--Spain--Primera-DivisionOsasuna-2-1-Eibar20210306-3162-1isaph3.xml'

# %%
file = os.path.join(data_dir,file)

tree = et.parse(file)
root = tree.getroot()

node_names = ['ID', 'start', 'end', 'code', 'pos_x', 'pos_y']
node_names_full = []
matrix = []
for node in root.iter('ALL_INSTANCES'):
    for instance in node.iter('instance'):
        if instance.find('code').text!='Empezar marca de tiempo':
            row=[]
            for node_name in node_names:
                row.append(instance.find(node_name).text)
            for label in instance.iter('label'):
                row.append(label.find('text').text)
                if label.find('group').text not in node_names_full and label.find('group').text not in node_names:
                    node_names_full.append(label.find('group').text)
            matrix.append(row)

# %%
df = pd.DataFrame(data = matrix,columns = node_names+node_names_full)
df.head()
# Out:
#   ID start    end                     code pos_x pos_y   Equipo  \
# 0  1     0  18.41          9. Sergi Enrich  52.5  34.1    Eibar
# 1  2     0  18.41          9. Sergi Enrich  52.5  34.1    Eibar
# 2  3  1.23  21.23           3. Pedro Bigas  34.4  38.4    Eibar
# 3  4  1.23  21.23           3. Pedro Bigas  34.4  38.4    Eibar
# 4  5  4.21  24.21  5. David Garcia Zubiria  25.9  60.3  Osasuna
#
#                  Accion     Medio
# 0        Pases precisos  1ª parte
# 1  Ataques posicionales  1ª parte
# 2  Ataques posicionales  1ª parte
# 3    Pases (inefectivo)  1ª parte
# 4  Ataques posicionales  1ª parte

# %%
df.rename({'code':'Player','Medio':'Half'},axis=1,inplace=True)
df.head()
# Out:
#   ID start    end                   Player pos_x pos_y   Equipo  \
# 0  1     0  18.41          9. Sergi Enrich  52.5  34.1    Eibar
# 1  2     0  18.41          9. Sergi Enrich  52.5  34.1    Eibar
# 2  3  1.23  21.23           3. Pedro Bigas  34.4  38.4    Eibar
# 3  4  1.23  21.23           3. Pedro Bigas  34.4  38.4    Eibar
# 4  5  4.21  24.21  5. David Garcia Zubiria  25.9  60.3  Osasuna
#
#                  Accion      Half
# 0        Pases precisos  1ª parte
# 1  Ataques posicionales  1ª parte
# 2  Ataques posicionales  1ª parte
# 3    Pases (inefectivo)  1ª parte
# 4  Ataques posicionales  1ª parte

# %%
for i in ['ID','start','end','pos_x','pos_y']:
    df[i] = pd.to_numeric(df[i])
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4028 entries, 0 to 4027
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      4028 non-null   int64
#  1   start   4028 non-null   float64
#  2   end     4028 non-null   float64
#  3   Player  4028 non-null   object
#  4   pos_x   4028 non-null   float64
#  5   pos_y   4028 non-null   float64
#  6   Equipo  4028 non-null   object
#  7   Accion  4028 non-null   object
#  8   Half    4028 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 283.3+ KB

# %%
df = df.sort_values('end').reset_index().drop('index',axis=1)
df
# Out:
#         ID    start      end                   Player  pos_x  pos_y   Equipo  \
# 0        1     0.00    18.41          9. Sergi Enrich   52.5   34.1    Eibar
# 1        2     0.00    18.41          9. Sergi Enrich   52.5   34.1    Eibar
# 2        3     1.23    21.23           3. Pedro Bigas   34.4   38.4    Eibar
# 3        4     1.23    21.23           3. Pedro Bigas   34.4   38.4    Eibar
# 4        5     4.21    24.21  5. David Garcia Zubiria   25.9   60.3  Osasuna
# ...    ...      ...      ...                      ...    ...    ...      ...
# 4023  4026  5847.14  5867.14          21. Inigo Perez   68.7   63.2  Osasuna
# 4024  4027  5847.14  5867.14          21. Inigo Perez   68.7   63.2  Osasuna
# 4025  4029  5848.19  5868.19                 39. Manu   67.6   54.3  Osasuna
# 4026  4028  5848.19  5868.19                 39. Manu   67.6   54.3  Osasuna
# 4027  4030  5849.51  5869.51          21. Inigo Perez   73.0   64.2  Osasuna
#
#                     Accion      Half
# 0           Pases precisos  1ª parte
# 1     Ataques posicionales  1ª parte
# 2     Ataques posicionales  1ª parte
# 3       Pases (inefectivo)  1ª parte
# 4     Ataques posicionales  1ª parte
# ...                    ...       ...
# 4023  Ataques posicionales  2ª parte
# 4024        Pases precisos  2ª parte
# 4025        Pases precisos  2ª parte
# 4026  Ataques posicionales  2ª parte
# 4027  Ataques posicionales  2ª parte
#
# [4028 rows x 9 columns]

# %%
df.Accion.value_counts()
# Out:
# Ataques posicionales                     1303
# Pases precisos                            689
# Contraataques                             256
# Pases (inefectivo)                        207
# Disputas (perdio)                         203
# Disputas (vencio)                         184
# Perdidas                                  160
# Rechaces                                  158
# Interceptaciones                          122
# Disputas por arriba (vencio)               93
# Disputas por arriba (perdio)               93
# Pases al area                              75
# Rechaces (en campo contrario)              56
# Tiros libres a favor                       46
# Corners                                    40
# Entradas (Acciones con exito)              29
# Conduccion                                 26
# Perdidas (en campo contrario)              24
# Faltas                                     21
# Interceptaciones (en campo contrario)      21
# Centros (inefectivo)                       21
# Regates (Acciones con exito)               19
# Entradas (Acciones sin  exito)             19
# Regates (Acciones sin  exito)              16
# Tiros                                      16
# Mal control de balon                       16
# Tiros libres indirectos                    16
# Centros (efectivo)                         12
# Pases de finalizacion (inefectivo)         10
# Error grave de gol                         10
# Tiros fuera (Porteros)                      7
# Tiros fuera                                 6
# Pases de finalizacion (efectivo)            6
# Fueras de juego                             6
# Errores de gol                              5
# Saque de banda a favor                      5
# Acciones a balon parado (inefectivo)        5
# Tiros en la porteria                        4
# Super Paradas                               4
# Tiros en la porteria (parado)               4
# Asistencias                                 3
# Goles encajados                             3
# Goles                                       3
#  (efectivo)                                 3
# Acciones a balon parado (efectivo)          2
# Tiros en el poste / larguero                1
# Name: Accion, dtype: int64

# %% [markdown]
# ### Shot Map - Eibar

# %%
df_tiros = df[(df['Accion']=='Tiros') & (df['Equipo']=='Eibar')]
df_tiros.head()
# Out:
#         ID    start      end                     Player  pos_x  pos_y Equipo  \
# 656    658   816.11   836.11                   17. Kike   84.1   36.6  Eibar
# 1509  1512  1982.50  2002.50  25. Bryan Gil Salvatierra   83.5   22.0  Eibar
# 1532  1531  2014.94  2034.94            9. Sergi Enrich   97.3   35.0  Eibar
# 1654  1655  2218.06  2238.06                   17. Kike   99.5   32.4  Eibar
# 1842  1844  2491.86  2511.86          4. Paulo Oliveira   92.8   29.8  Eibar
#
#      Accion      Half
# 656   Tiros  1ª parte
# 1509  Tiros  1ª parte
# 1532  Tiros  1ª parte
# 1654  Tiros  1ª parte
# 1842  Tiros  1ª parte

# %%
for i in df_tiros.values:
    print(i[3])
# Out:
# 17. Kike
# 25. Bryan Gil Salvatierra
# 9. Sergi Enrich
# 17. Kike
# 4. Paulo Oliveira
# 12. Yoshinori Muto
# 12. Yoshinori Muto

# %%
pitch = Pitch(label=False,axis=False,pitch_type='uefa')
fig,ax= pitch.draw(figsize=(13,7))

for i in df_tiros.values:
    plt.text(i[4]+1,i[5]-0.5,i[3],size=8,color='black')
    

sc = pitch.scatter(df_tiros.pos_x,df_tiros.pos_y,
                  c='red',
                  s=100,ax=ax)
plt.title('{} - {}'.format(df_tiros.Accion.values[0],df_tiros.Equipo.values[0]));

# %% [markdown]
# ### Passing Map - Bryan Gil

# %%
df.head(30)
# Out:
#     ID  start    end                   Player  pos_x  pos_y   Equipo  \
# 0    1   0.00  18.41          9. Sergi Enrich   52.5   34.1    Eibar
# 1    2   0.00  18.41          9. Sergi Enrich   52.5   34.1    Eibar
# 2    3   1.23  21.23           3. Pedro Bigas   34.4   38.4    Eibar
# 3    4   1.23  21.23           3. Pedro Bigas   34.4   38.4    Eibar
# 4    5   4.21  24.21  5. David Garcia Zubiria   25.9   60.3  Osasuna
# 5    6   4.21  24.21  5. David Garcia Zubiria   25.9   60.3  Osasuna
# 6    7   4.21  24.21  5. David Garcia Zubiria   25.9   60.3  Osasuna
# 7    8   4.21  24.21  5. David Garcia Zubiria   25.9   60.3  Osasuna
# 8    9   6.28  26.28              23. Arbilla   64.7   10.5    Eibar
# 9   10   6.28  26.28              23. Arbilla   64.7   10.5    Eibar
# 10  11   6.28  26.28              23. Arbilla   64.7   10.5    Eibar
# 11  12   6.28  26.28              23. Arbilla   64.7   10.5    Eibar
# 12  13   6.28  26.28              23. Arbilla   64.7   10.5    Eibar
# 13  14   7.16  27.16                 17. Kike   78.3   13.6    Eibar
# 14  19   8.02  28.02  5. David Garcia Zubiria   26.3   49.0  Osasuna
# 15  18   8.02  28.02  5. David Garcia Zubiria   26.3   49.0  Osasuna
# 16  16   8.02  28.02                 17. Kike   78.7   19.0    Eibar
# 17  15   8.02  28.02  5. David Garcia Zubiria   26.3   49.0  Osasuna
# 18  17   8.02  28.02                 17. Kike   78.7   19.0    Eibar
# 19  21   9.44  29.44          24. Lucas Torro   26.8   49.9  Osasuna
# 20  22   9.44  29.44          24. Lucas Torro   26.8   49.9  Osasuna
# 21  23   9.44  29.44          24. Lucas Torro   26.8   49.9  Osasuna
# 22  24   9.44  29.44          24. Lucas Torro   26.8   49.9  Osasuna
# 23  25  12.32  32.32                 39. Manu   25.3   64.0  Osasuna
# 24  26  12.32  32.32                 39. Manu   25.3   64.0  Osasuna
# 25  27  14.19  34.19        4. Paulo Oliveira   47.2   14.5    Eibar
# 26  28  14.19  34.19        4. Paulo Oliveira   47.2   14.5    Eibar
# 27  29  14.19  34.19        4. Paulo Oliveira   47.2   14.5    Eibar
# 28  30  14.19  34.19        4. Paulo Oliveira   47.2   14.5    Eibar
# 29  34  16.57  36.57                 39. Manu   24.9   62.3  Osasuna
#
#                                    Accion      Half
# 0                          Pases precisos  1ª parte
# 1                    Ataques posicionales  1ª parte
# 2                    Ataques posicionales  1ª parte
# 3                      Pases (inefectivo)  1ª parte
# 4                    Ataques posicionales  1ª parte
# 5                      Pases (inefectivo)  1ª parte
# 6                        Interceptaciones  1ª parte
# 7                    Ataques posicionales  1ª parte
# 8                    Ataques posicionales  1ª parte
# 9                          Pases precisos  1ª parte
# 10                   Ataques posicionales  1ª parte
# 11  Interceptaciones (en campo contrario)  1ª parte
# 12                       Interceptaciones  1ª parte
# 13                   Ataques posicionales  1ª parte
# 14          Entradas (Acciones con exito)  1ª parte
# 15                      Disputas (vencio)  1ª parte
# 16                               Perdidas  1ª parte
# 17                   Ataques posicionales  1ª parte
# 18                      Disputas (perdio)  1ª parte
# 19                               Rechaces  1ª parte
# 20                   Ataques posicionales  1ª parte
# 21                   Ataques posicionales  1ª parte
# 22                         Pases precisos  1ª parte
# 23                     Pases (inefectivo)  1ª parte
# 24                   Ataques posicionales  1ª parte
# 25                     Pases (inefectivo)  1ª parte
# 26                       Interceptaciones  1ª parte
# 27                   Ataques posicionales  1ª parte
# 28                   Ataques posicionales  1ª parte
# 29                   Ataques posicionales  1ª parte

# %%
instat_x = 105
instat_y = 68

# %%
df_pases = df[df['Accion'].str.contains('Pases precisos') | df['Accion'].str.contains('Asistencias')]
df_pases.head()
# Out:
#     ID  start    end            Player  pos_x  pos_y   Equipo          Accion  \
# 0    1   0.00  18.41   9. Sergi Enrich   52.5   34.1    Eibar  Pases precisos
# 9   10   6.28  26.28       23. Arbilla   64.7   10.5    Eibar  Pases precisos
# 22  24   9.44  29.44   24. Lucas Torro   26.8   49.9  Osasuna  Pases precisos
# 31  31  16.57  36.57          39. Manu   24.9   62.3  Osasuna  Pases precisos
# 33  35  19.64  39.64  14. Ruben Garcia   40.8   64.5  Osasuna  Pases precisos
#
#         Half
# 0   1ª parte
# 9   1ª parte
# 22  1ª parte
# 31  1ª parte
# 33  1ª parte

# %%
def detalle_jugadas(df):

    df['Rec_x'] = 0
    df['Rec_y'] = 0
    df['Pase_Receptor'] = ''
    df['Resultado_Accion'] = ''

    for i,j in df[(df['Accion'].str.contains('Pases precisos')) | (df['Accion'].str.contains('Centros'))].iterrows():
        player = df.loc[i,'Player']
        team = df.loc[i,'Equipo']

        for k,h in df[i:].iterrows():
            if player!=h['Player'] : #and h['Accion']=='Ataques posicionales':
                df.loc[i,'Pase_Receptor']= h['Player']
                if team==h['Equipo']:
                    df.loc[i,'Rec_x']= h['pos_x']
                    df.loc[i,'Rec_y']= h['pos_y']
                    df.loc[i,'Resultado_Accion']= 'Completado'
                else:
                    df.loc[i,'Resultado_Accion']= 'No Completado'
                    df.loc[i,'Rec_x']= instat_x-h['pos_x']
                    df.loc[i,'Rec_y']= instat_y-h['pos_y']
                break

    for i,j in df[(df['Accion'].str.contains('Asistencias'))].iterrows():
        player = df.loc[i,'Player']
        team = df.loc[i,'Equipo']
        for k,h in df[i:].iterrows():        
            if player!=h['Player'] and team==h['Equipo'] and h['Accion']=='Goles':
                df.loc[i,'Rec_x']= h['pos_x']
                df.loc[i,'Rec_y']= h['pos_y']
                df.loc[i,'Resultado_Accion']= 'Completado'
                df.loc[i,'Pase_Receptor']= h['Player']
                break

    for i,j in df[(df['Accion'].str.contains('Conduccion'))].iterrows():
        player = df.loc[i,'Player']
        for k,h in df[i:].iterrows():
            if player==h['Player'] and (j['pos_x']!=h['pos_x'] or j['pos_y']!=h['pos_y']):
                df.loc[i,'Rec_x']= h['pos_x']
                df.loc[i,'Rec_y']= h['pos_y']
                df.loc[i,'Resultado_Accion'] = h['Accion']

                break
    return df

df = detalle_jugadas(df)

# %%
df_pases = df[(df['Accion'].str.contains('Pases precisos')) | (df['Accion'].str.contains('Asistencias')) | (df['Accion'].str.contains('Centros')) ]

# %%
df_pases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 725 entries, 0 to 4025
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                725 non-null    int64
#  1   start             725 non-null    float64
#  2   end               725 non-null    float64
#  3   Player            725 non-null    object
#  4   pos_x             725 non-null    float64
#  5   pos_y             725 non-null    float64
#  6   Equipo            725 non-null    object
#  7   Accion            725 non-null    object
#  8   Half              725 non-null    object
#  9   Rec_x             725 non-null    float64
#  10  Rec_y             725 non-null    float64
#  11  Pase_Receptor     725 non-null    object
#  12  Resultado_Accion  725 non-null    object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 79.3+ KB

# %%
df_pases_filt = df_pases[(df_pases['Equipo']=='Eibar') & (df_pases['Player'].str.contains('Bryan Gil'))]
df_pases_filt.head()
# Out:
#         ID    start      end                     Player  pos_x  pos_y Equipo  \
# 208    210   217.56   237.56  25. Bryan Gil Salvatierra   48.0   50.5  Eibar
# 225    227   248.20   268.20  25. Bryan Gil Salvatierra  101.6   62.4  Eibar
# 652    654   814.55   834.55  25. Bryan Gil Salvatierra   88.0   52.5  Eibar
# 1296  1297  1697.15  1717.15  25. Bryan Gil Salvatierra   61.4   61.1  Eibar
# 1380  1382  1813.43  1833.43  25. Bryan Gil Salvatierra   92.1   65.0  Eibar
#
#                     Accion      Half  Rec_x  Rec_y              Pase_Receptor  \
# 208         Pases precisos  1ª parte   57.8   39.2            9. Sergi Enrich
# 225   Centros (inefectivo)  1ª parte   95.8   34.8                   17. Kike
# 652         Pases precisos  1ª parte   84.1   36.6          1. Sergio Herrera
# 1296        Pases precisos  1ª parte   61.4   61.1  2. Ignacio Vidal Miralles
# 1380        Pases precisos  1ª parte   81.4   60.6                  18. Recio
#
#      Resultado_Accion
# 208        Completado
# 225        Completado
# 652     No Completado
# 1296    No Completado
# 1380       Completado

# %%
df[df['Accion'].str.contains('Centros')].head(5)
# Out:
#       ID   start     end                     Player  pos_x  pos_y   Equipo  \
# 90    91   84.60  104.60                   39. Manu   97.6   66.4  Osasuna
# 106  109  102.11  122.11                   39. Manu   95.2   59.2  Osasuna
# 225  227  248.20  268.20  25. Bryan Gil Salvatierra  101.6   62.4    Eibar
# 237  239  264.28  284.28                  18. Recio   79.3    7.9    Eibar
# 323  325  358.73  378.73  2. Ignacio Vidal Miralles   74.1   17.2  Osasuna
#
#                    Accion      Half  Rec_x  Rec_y       Pase_Receptor  \
# 90   Centros (inefectivo)  1ª parte   97.7   64.8  12. Yoshinori Muto
# 106    Centros (efectivo)  1ª parte   96.0   36.1      3. Pedro Bigas
# 225  Centros (inefectivo)  1ª parte   95.8   34.8            17. Kike
# 237    Centros (efectivo)  1ª parte   89.5   30.8            17. Kike
# 323  Centros (inefectivo)  1ª parte   92.5   35.6   4. Paulo Oliveira
#
#     Resultado_Accion
# 90     No Completado
# 106    No Completado
# 225       Completado
# 237       Completado
# 323    No Completado

# %%
# Setup the pitch
pitch = Pitch(pitch_type='uefa', pitch_color='#386D38', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#386D38')

# Plot the completed passes
df_pases_fail = df_pases_filt[df_pases_filt.Resultado_Accion=='No Completado']
pitch.arrows(df_pases_fail.pos_x, df_pases_fail.pos_y,
             df_pases_fail.Rec_x, df_pases_fail.Rec_y, width=2,
             headwidth=10, headlength=10, color='red', ax=ax, label='uncompleted passes')

df_pases_ok = df_pases_filt[df_pases_filt.Resultado_Accion=='Completado']

pitch.arrows(df_pases_ok.pos_x, df_pases_ok.pos_y,
             df_pases_ok.Rec_x, df_pases_ok.Rec_y, width=2,
             headwidth=10, headlength=10, color='blue', ax=ax, label='completed passes')

# setup the legend
ax.legend( handlelength=5, edgecolor='None', fontsize=15, loc='upper left')

# Set the title
ax.set_title('{} passes vs {}'.format(df_pases_filt.Player.values[0],'Osasuna'), fontsize=30)
plt.show();
